# %% [markdown]
# # Post training analysis
#
# You probably have an observation that corresponds to your sample/patient ID. For this public dataset, this observation is `adata.obs["subject"]`.
# We can use it to count (or get the proportion) of populations per patient (for more details, see [`scyan.tools.count_cell_populations`](../../api/analysis/#scyan.tools.count_cell_populations)).
#
# Suppose you have the trained model below:

# %%
import scyan
# Out:
# Global seed set to 0

# %%
adata, marker_pop_matrix = scyan.data.load("aml", table="groups_demo")

model = scyan.Scyan(adata, marker_pop_matrix, batch_key="subject", temperature=0.5)

model.fit()
model.predict();

# %% [markdown]
# Now, you can use [`scyan.tools.count_cell_populations`](../../api/analysis/#scyan.tools.count_cell_populations)) to count (or get the frequency) of every population for every patient.

# %%
scyan.tools.count_cell_populations(adata, "subject", normalize=True) # Remove 'normalize' to get absolute counts
# Out:
#          Basophils  CD16+ NK cells  CD16- NK cells  CD34+CD38+CD123+ HSPCs  \
# subject
# H1        0.010254        0.022770        0.038378                0.002415
# H2        0.007944        0.013745        0.042464                0.004256
#
#          CD34+CD38+CD123- HSPCs  CD34+CD38lo HSCs  CD4 T cells  CD8 T cells  \
# subject
# H1                     0.029643          0.009136     0.254005     0.177911
# H2                     0.040289          0.008196     0.260269     0.216639
#
#          Mature B cells  Monocytes  Plasma B cells  Pre B cells  Pro B cells  \
# subject
# H1             0.161765   0.222210        0.002608     0.055559     0.001380
# H2             0.128022   0.157183        0.002995     0.092652     0.006494
#
#              pDCs
# subject
# H1       0.011965
# H2       0.018852

# %% [markdown]
# You can also compute the Mean Metal Intensity (MMI) or Mean Fluorescence Intensity (MFI) per population.

# %%
scyan.tools.mean_intensities(adata)
# Out:
#                           CD45RA     CD133      CD19      CD22     CD11b  \
# scyan_pop
# Basophils              -0.650394 -0.268267 -0.552603 -0.457793  0.396196
# CD16+ NK cells          0.429159  0.039623 -0.504274 -0.399736 -0.044361
# CD16- NK cells          0.617091 -0.036940 -0.516867 -0.423595 -0.073872
# CD34+CD38+CD123+ HSPCs -0.351304  0.012413 -0.559001 -0.373805 -0.507419
# CD34+CD38+CD123- HSPCs -0.609862  0.214337 -0.485652 -0.414402 -0.532063
# CD34+CD38lo HSCs       -0.731283  0.572578 -0.524156 -0.421885 -0.534525
# CD4 T cells            -0.295373 -0.141642 -0.524427 -0.440280 -0.510504
# CD8 T cells             0.079129  0.111491 -0.476057 -0.381079 -0.448947
# Mature B cells          0.911623  0.211303  1.864359  1.998897 -0.347785
# Monocytes              -0.412901 -0.067365 -0.498013 -0.374444  1.665887
# Plasma B cells          0.201696  0.074160  1.524368 -0.186502 -0.453867
# Pre B cells             0.131272 -0.122729  1.509052  0.187924 -0.521172
# Pro B cells            -0.559085 -0.333103  1.252164 -0.176096 -0.561868
# pDCs                   -0.063470 -0.232049 -0.548017 -0.424172 -0.511977
#
#                              CD4       CD8      CD34      Flt3      CD20  ...  \
# scyan_pop                                                                 ...
# Basophils              -0.548937 -0.531312 -0.168299  0.074983 -0.414086  ...
# CD16+ NK cells         -0.535947 -0.046856 -0.242640 -0.014037 -0.375131  ...
# CD16- NK cells         -0.555595 -0.225319 -0.275629 -0.057550 -0.389450  ...
# CD34+CD38+CD123+ HSPCs -0.580643 -0.519913  3.186022  0.275922 -0.417951  ...
# CD34+CD38+CD123- HSPCs -0.614568 -0.514752  3.890719 -0.059665 -0.416212  ...
# CD34+CD38lo HSCs       -0.544957 -0.494022  4.554794 -0.144784 -0.398635  ...
# CD4 T cells             1.329323 -0.427116 -0.276332 -0.035129 -0.402096  ...
# CD8 T cells            -0.489495  1.933592 -0.219517  0.052118 -0.276953  ...
# Mature B cells         -0.538452 -0.487599 -0.010168  0.048773  1.667092  ...
# Monocytes              -0.261314 -0.494251 -0.224383 -0.044085 -0.414174  ...
# Plasma B cells         -0.561811 -0.504388 -0.124410  0.078506  0.550805  ...
# Pre B cells            -0.626996 -0.529723 -0.161254 -0.077520  0.561925  ...
# Pro B cells            -0.673293 -0.541717  3.297247 -0.214200 -0.345517  ...
# pDCs                   -0.193071 -0.528303  0.029004  0.160860 -0.424925  ...
#
#                             CD44      CD38      CD13       CD3      CD61  \
# scyan_pop
# Basophils              -0.284314  1.406207  0.637722 -0.891677  0.265756
# CD16+ NK cells         -1.507957  0.466374 -0.472155 -0.886889 -0.226285
# CD16- NK cells         -1.070441  0.089779 -0.488968 -0.867317 -0.293461
# CD34+CD38+CD123+ HSPCs  0.225342  1.671787  0.289864 -0.914969 -0.278578
# CD34+CD38+CD123- HSPCs -0.311456  1.469275  0.955971 -0.890441 -0.174836
# CD34+CD38lo HSCs       -0.342297 -0.206957  0.433710 -0.876245 -0.218498
# CD4 T cells             0.093543 -0.542321 -0.321435  1.133218 -0.081243
# CD8 T cells            -0.039015 -0.678655 -0.364914  1.033786 -0.108180
# Mature B cells          0.128547 -0.377311 -0.434820 -0.873354 -0.161541
# Monocytes               0.749248  0.376513  0.885435 -0.861972  0.527021
# Plasma B cells          0.042425  2.851589  0.474107 -0.924977 -0.289208
# Pre B cells            -1.425771  2.230621  0.298657 -0.911489 -0.222837
# Pro B cells            -1.591416  2.246263  0.417199 -0.945659 -0.314636
# pDCs                    0.009245  0.512073  0.157338 -0.903646 -0.152739
#
#                            CD117     CD49d    HLA-DR      CD64      CD41
# scyan_pop
# Basophils              -0.300440 -0.173134 -0.741070 -0.457706  0.262590
# CD16+ NK cells         -0.362133 -0.089616 -0.805124 -0.466676 -0.236655
# CD16- NK cells         -0.332809 -0.296473 -0.810709 -0.482301 -0.297818
# CD34+CD38+CD123+ HSPCs  0.463557  0.585703  1.646557 -0.451720  0.098062
# CD34+CD38+CD123- HSPCs  2.778629  0.445701  0.923888 -0.445091 -0.000402
# CD34+CD38lo HSCs        2.818573  0.079687  0.371171 -0.452750 -0.100354
# CD4 T cells             0.140566 -0.358566 -0.819418 -0.491286 -0.324514
# CD8 T cells             0.092483 -0.319089 -0.812974 -0.500470 -0.321964
# Mature B cells         -0.334423  0.357441  1.126832 -0.367159  0.124034
# Monocytes              -0.330762  0.317935  0.563200  1.819941  0.679062
# Plasma B cells         -0.362624  0.755404 -0.749683 -0.487577 -0.349019
# Pre B cells            -0.360281  0.278293  1.204377 -0.453162  0.042651
# Pro B cells            -0.293518  0.483934  1.147215 -0.472210 -0.096100
# pDCs                   -0.318971  0.696646  1.004990 -0.445509  0.064542
#
# [14 rows x 32 columns]

# %% [markdown]
# And also group per patient first (for more details, see [`scyan.tools.mean_intensities`](../../api/analysis/#scyan.tools.mean_intensities)), and compute the MMI on raw intensities.

# %%
adata.layers["raw"] = adata.raw.X # Save raw intensities as a new layer
scyan.tools.mean_intensities(adata, groupby=["subject", "scyan_pop"], layer="raw") # Group by subject and scyan populations predictions
# Out:
#                                    CD45RA     CD133       CD19       CD22  \
# subject scyan_pop
# H1      Basophils                1.986409  0.493086   0.376089   0.395282
#         CD16+ NK cells           5.608107  0.975891   0.679313   0.731768
#         CD16- NK cells           6.295384  1.008622   0.683303   0.698879
#         CD34+CD38+CD123+ HSPCs   2.856423  1.050163   0.436065   0.966892
#         CD34+CD38+CD123- HSPCs   2.272032  1.331688   0.713006   0.665518
#         CD34+CD38lo HSCs         1.486565  1.668337   0.520531   0.578797
#         CD4 T cells              3.071119  0.786612   0.615706   0.584064
#         CD8 T cells              4.150362  1.332659   0.976140   0.988981
#         Mature B cells           8.798116  1.351135  27.155048  23.170298
#         Monocytes                2.944548  0.830465   0.693846   0.816555
#         Plasma B cells           5.667675  1.182915  19.659534   2.242643
#         Pre B cells              5.170161  0.951324  17.165524   6.232593
#         Pro B cells              2.424829  0.659077  12.980412   2.026644
#         pDCs                     3.191568  0.671008   0.508593   0.639993
# H2      Basophils                0.915726  0.042205   0.101274   0.118964
#         CD16+ NK cells          14.340820  0.135194   0.068921   0.024861
#         CD16- NK cells          14.820559  0.060240   0.085353   0.018483
#         CD34+CD38+CD123+ HSPCs   2.958258  0.381977   0.065748   0.358542
#         CD34+CD38+CD123- HSPCs   1.605877  0.593989   0.554679   0.311576
#         CD34+CD38lo HSCs         1.070537  1.230387   0.263850   0.266859
#         CD4 T cells              3.860143  0.030285   0.082768   0.000332
#         CD8 T cells              7.151220  0.104419   0.165572   0.063777
#         Mature B cells          16.538395  0.141821  27.822359  31.231659
#         Monocytes                1.876170  0.083837   0.218579   0.314857
#         Plasma B cells           6.861670  0.175923  20.177567   0.437430
#         Pre B cells              6.057568  0.099472  22.813587   3.415911
#         Pro B cells              1.884224  0.115019  15.290460   1.573644
#         pDCs                     6.061659  0.085638   0.077789   0.299907
#
#                                     CD11b       CD4        CD8        CD34  \
# subject scyan_pop
# H1      Basophils                7.275185  0.570578   0.249206    1.139696
#         CD16+ NK cells           4.026606  0.680343   4.386758    1.064434
#         CD16- NK cells           3.867707  0.848318   2.777549    1.049212
#         CD34+CD38+CD123+ HSPCs   1.321587  0.506231   0.346509   38.997448
#         CD34+CD38+CD123- HSPCs   1.100386  0.394143   0.352711   56.912209
#         CD34+CD38lo HSCs         0.995732  0.602956   0.444121   83.757072
#         CD4 T cells              1.247325  6.938007   1.066971    0.983536
#         CD8 T cells              1.717226  0.957600  39.204407    1.295235
#         Mature B cells           2.158309  0.727070   0.605473    2.219918
#         Monocytes               30.937788  1.402935   0.491311    1.130986
#         Plasma B cells           1.639651  0.692706   0.501011    1.748886
#         Pre B cells              1.332613  0.496028   0.409444    1.724375
#         Pro B cells              1.293596  0.292935   0.255259   36.326374
#         pDCs                     1.458513  1.645702   0.326985    1.864745
# H2      Basophils               14.215103  0.357817   0.157507    1.310967
#         CD16+ NK cells           4.115219  0.071949   2.346740    0.283892
#         CD16- NK cells           4.126052  0.113824   2.746734    0.238002
#         CD34+CD38+CD123+ HSPCs   0.525630  0.297799   0.215447   35.837738
#         CD34+CD38+CD123- HSPCs   0.362456  0.192000   0.259792   66.735847
#         CD34+CD38lo HSCs         0.347950  0.332126   0.409119  110.724960
#         CD4 T cells              0.333140  9.763877   0.545758    0.313381
#         CD8 T cells              0.599065  0.199436  44.128738    0.412592
#         Mature B cells           1.258774  0.093250   0.097542    0.639560
#         Monocytes               73.107124  1.462503   0.258031    0.467654
#         Plasma B cells           0.587711  0.073961   0.129682    0.562908
#         Pre B cells              0.290858 -0.007795  -0.000740    0.581633
#         Pro B cells              0.341296  0.073244   0.124455   38.926716
#         pDCs                     0.703867  1.589890   0.121227    2.150551
#
#                                     Flt3       CD20  ...        CD44  \
# subject scyan_pop                                    ...
# H1      Basophils               2.338620   0.347152  ...  119.762558
#         CD16+ NK cells          3.060574   0.540708  ...   35.507240
#         CD16- NK cells          2.848926   0.513101  ...   69.376862
#         CD34+CD38+CD123+ HSPCs  1.928108   0.395798  ...  152.670013
#         CD34+CD38+CD123- HSPCs  2.733735   0.350593  ...   89.751740
#         CD34+CD38lo HSCs        0.893181   0.425907  ...   92.658684
#         CD4 T cells             3.391114   0.442165  ...  150.552185
#         CD8 T cells             3.566292   1.030188  ...  130.041000
#         Mature B cells          4.744723  36.949535  ...  156.927643
#         Monocytes               3.718187   0.363582  ...  258.635193
#         Plasma B cells          4.702974  29.884359  ...  199.968704
#         Pre B cells             3.814552  25.460480  ...   55.258602
#         Pro B cells             0.863352   0.765296  ...   36.891682
#         pDCs                    4.074918   0.355200  ...  125.065582
# H2      Basophils               1.074977   0.075126  ...  103.389381
#         CD16+ NK cells          0.298637   0.148113  ...   29.166374
#         CD16- NK cells          0.395923   0.142470  ...   56.053093
#         CD34+CD38+CD123+ HSPCs  1.595168   0.084368  ...  230.890076
#         CD34+CD38+CD123- HSPCs  0.787894   0.130012  ...  155.974304
#         CD34+CD38lo HSCs        0.789538   0.151043  ...  130.315933
#         CD4 T cells             0.528879   0.092207  ...  189.026520
#         CD8 T cells             0.547044   0.679588  ...  154.103287
#         Mature B cells          0.505293   6.136407  ...  182.636673
#         Monocytes               0.564537   0.003870  ...  334.845856
#         Plasma B cells          0.948243   1.027096  ...  289.815002
#         Pre B cells             0.585170   2.284225  ...   23.179985
#         Pro B cells             0.643800   0.680909  ...   25.168499
#         pDCs                    1.322746   0.048709  ...  171.654968
#
#                                        CD38      CD13         CD3      CD61  \
# subject scyan_pop
# H1      Basophils                100.605736  3.674787    1.213088  2.282390
#         CD16+ NK cells            41.743050  0.650196    1.203889  1.098937
#         CD16- NK cells            31.229914  0.685470    2.317920  1.093011
#         CD34+CD38+CD123+ HSPCs   124.196754  2.746622    1.002469  1.254052
#         CD34+CD38+CD123- HSPCs    88.104256  4.651646    1.321161  1.375749
#         CD34+CD38lo HSCs           7.541362  2.530544    1.443064  1.152390
#         CD4 T cells                5.386613  1.179145  352.141571  1.560779
#         CD8 T cells                3.438758  1.018321  306.202301  1.586440
#         Mature B cells             7.046521  0.995778    1.468791  1.374248
#         Monocytes                 23.406231  4.813964    1.589009  2.954769
#         Plasma B cells           627.806702  3.217886    0.877295  0.998995
#         Pre B cells              273.316589  2.782434    1.125969  1.343363
#         Pro B cells              207.518402  2.757904    0.606259  1.414532
#         pDCs                      35.281631  2.771540    1.173100  1.566913
# H2      Basophils                139.982208  6.344880    0.442017  0.924717
#         CD16+ NK cells            43.398842  0.586796    0.665898  0.047339
#         CD16- NK cells            34.434376  0.415240    1.386957  0.012092
#         CD34+CD38+CD123+ HSPCs   133.866776  3.150034    0.339150  0.074531
#         CD34+CD38+CD123- HSPCs   136.932068  8.245744    0.556074  0.259154
#         CD34+CD38lo HSCs           8.440727  6.864863    0.705739  0.201503
#         CD4 T cells                7.109939  0.920051  394.903107  0.329016
#         CD8 T cells                3.322930  0.778158  263.540344  0.263961
#         Mature B cells             5.340249  0.513729    0.620435  0.010914
#         Monocytes                 31.026518  8.999647    0.784851  1.332650
#         Plasma B cells          1203.572754  6.069797    0.086889  0.194226
#         Pre B cells              345.301666  3.141733    0.279537  0.230566
#         Pro B cells              293.153625  3.609714    0.200072  0.308178
#         pDCs                      33.804962  2.574159    0.402219  0.239032
#
#                                    CD117      CD49d      HLA-DR       CD64  \
# subject scyan_pop
# H1      Basophils               0.209436   4.780606    1.341148   0.661162
#         CD16+ NK cells          0.083937   4.767233    0.678394   0.625413
#         CD16- NK cells          0.168797   4.357325    0.683977   0.607634
#         CD34+CD38+CD123+ HSPCs  1.671097  11.712677  240.479172   0.754386
#         CD34+CD38+CD123- HSPCs  9.110744   9.249640   88.386887   0.783576
#         CD34+CD38lo HSCs        7.577510   6.462340   24.428492   0.731176
#         CD4 T cells             0.932472   4.451127    0.602062   0.550161
#         CD8 T cells             0.872374   4.559689    0.674333   0.525241
#         Mature B cells          0.153610   8.711406   99.270035   1.320503
#         Monocytes               0.159126   8.524929   68.860947  30.551876
#         Plasma B cells          0.102917  14.280210    1.260216   0.594585
#         Pre B cells             0.126010   9.248890   90.541924   0.796042
#         Pro B cells             0.500515  11.990647   77.854385   0.682467
#         pDCs                    0.290906  12.345481   59.729877   0.798699
# H2      Basophils               0.054078   2.571585    0.844412   0.280441
#         CD16+ NK cells          0.009071   3.055510    0.296669   0.127720
#         CD16- NK cells          0.059115   2.033366    0.276626   0.112255
#         CD34+CD38+CD123+ HSPCs  1.788927   4.520397  416.044891   0.385602
#         CD34+CD38+CD123- HSPCs  7.831870   4.667525  194.893707   0.360300
#         CD34+CD38lo HSCs        7.791861   2.549601   63.731537   0.225945
#         CD4 T cells             0.890560   1.608938    0.178915   0.072233
#         CD8 T cells             0.772304   1.817082    0.255462   0.043412
#         Mature B cells          0.004257   3.444458  194.096481   0.372320
#         Monocytes              -0.001538   2.515167   60.466721  17.380497
#         Plasma B cells         -0.000759   8.732924    0.824486   0.081288
#         Pre B cells            -0.003133   3.827254  238.750092   0.313266
#         Pro B cells             0.067095   5.549325  219.779602   0.403264
#         pDCs                    0.017372   5.219604  165.933487   0.371463
#
#                                     CD41
# subject scyan_pop
# H1      Basophils               2.032313
#         CD16+ NK cells          0.736148
#         CD16- NK cells          0.727256
#         CD34+CD38+CD123+ HSPCs  1.429936
#         CD34+CD38+CD123- HSPCs  1.214577
#         CD34+CD38lo HSCs        1.020850
#         CD4 T cells             0.632005
#         CD8 T cells             0.674313
#         Mature B cells          1.430831
#         Monocytes               2.761205
#         Plasma B cells          0.734214
#         Pre B cells             1.260106
#         Pro B cells             0.971236
#         pDCs                    1.321739
# H2      Basophils               0.659706
#         CD16+ NK cells         -0.029709
#         CD16- NK cells         -0.059463
#         CD34+CD38+CD123+ HSPCs  0.838054
#         CD34+CD38+CD123- HSPCs  0.640134
#         CD34+CD38lo HSCs        0.288404
#         CD4 T cells            -0.062082
#         CD8 T cells            -0.052153
#         Mature B cells          0.726641
#         Monocytes               1.242245
#         Plasma B cells         -0.063147
#         Pre B cells             0.830309
#         Pro B cells             0.721673
#         pDCs                    0.809597
#
# [28 rows x 32 columns]

# %% [markdown]
# ## Inverse transformations after batch effect removal
#
# Suppose you removed the batch effect, and you stored the new scaled expressions in a layer called `"corrected"`.
# Now, you may want to compute MMI of raw intensities after batch effect removal.
#
# As `adata.layers["corrected"]` is transformed and scaled, you have to unscale it and reverse the transformation you performed (i.e., [`scyan.tools.auto_logicle_transform`](../../api/preprocessing/#scyan.tools.auto_logicle_transform) or [`scyan.tools.asinh_transform`](../../api/preprocessing/#scyan.tools.asinh_transform)) to get raw data.

# %%
adata.obsm["corrected"] = model.batch_effect_correction().numpy()

# %%
adata.obsm["raw_corrected"] = scyan.tools.unscale(adata, obsm="corrected", obsm_names=model.var_names)
adata.obsm["raw_corrected"] = scyan.tools.inverse_transform(adata, obsm="raw_corrected")
# Out:
# INFO:scyan.tools.preprocessing:Performing inverse asinh transform

# %% [markdown]
# We can now compute MMI of our raw corrected intensities.

# %%
scyan.tools.mean_intensities(adata, obsm="raw_corrected", obsm_names=model.var_names)
# Out:
#                              CD19       CD4        CD8       CD34       CD20  \
# scyan_pop
# Basophils                0.429488  0.510508   0.290463   1.377057   0.550543
# CD16+ NK cells           0.672736  0.536981   3.896622   1.051605   0.562235
# CD16- NK cells           0.690447  0.604873   2.679280   1.025616   0.692418
# CD34+CD38+CD123+ HSPCs   0.457046  0.390945   0.410860  36.347572   0.686906
# CD34+CD38+CD123- HSPCs   0.788179  0.348047   0.317661  57.771240   0.611960
# CD34+CD38lo HSCs         0.598596  0.529740   0.418615  87.073868   0.590343
# CD4 T cells              0.593423  7.524443   0.865098   0.954125   0.619869
# CD8 T cells              0.913638  0.701833  37.664074   1.237075   1.025258
# Mature B cells          26.167215  0.607499   0.478030   2.039176  30.309441
# Monocytes                0.661866  1.459498   0.432541   1.100335   0.531442
# Plasma B cells          18.892992  0.544730   0.415189   1.580847  20.889675
# Pre B cells             17.897806  0.374716   0.334978   1.560526  17.096428
# Pro B cells             13.447527  0.257741   0.228887  36.031006   1.684929
# pDCs                     0.547335  1.578142   0.301949   2.324360   0.697984
#
#                               CD45       CD123      CD11c         CD7  \
# scyan_pop
# Basophils               235.222748  153.498077   1.862542    0.368591
# CD16+ NK cells          811.934265    0.644600   1.772125  119.254395
# CD16- NK cells          790.716797    0.731300   1.434953  331.414093
# CD34+CD38+CD123+ HSPCs  100.853760  156.172195   1.668221    0.712719
# CD34+CD38+CD123- HSPCs   88.048599    3.743180   1.694117    0.558762
# CD34+CD38lo HSCs        147.053253    3.276937   1.322454    0.390848
# CD4 T cells             858.966309    0.624171   0.914578   19.241194
# CD8 T cells             947.754700    0.628787   0.752963   26.448017
# Mature B cells          700.662048    0.969035   1.459214    0.259585
# Monocytes               563.018433    3.650350  42.869503    0.265577
# Plasma B cells          304.117859    2.688596   1.130242    0.505918
# Pre B cells             326.330872    2.778097   1.329172    0.367880
# Pro B cells              75.360725    1.347940   1.469086    0.728793
# pDCs                    226.388489  183.181137   1.341939    0.564765
#
#                              CD16        CD38         CD3      HLA-DR  \
# scyan_pop
# Basophils                0.460482  100.557655    1.020929    0.791476
# CD16+ NK cells          72.335281   41.521133    0.909237    0.727547
# CD16- NK cells           2.000364   30.472807    1.913716    0.771144
# CD34+CD38+CD123+ HSPCs   0.621967  115.002029    0.753280  195.923553
# CD34+CD38+CD123- HSPCs   0.586755   88.506897    1.029860   82.074982
# CD34+CD38lo HSCs         0.575877    7.691396    1.143528   26.142094
# CD4 T cells              0.465529    6.425010  349.316284    0.597908
# CD8 T cells              0.554922    3.316784  284.936523    0.716348
# Mature B cells           0.536168    6.935181    1.194092  101.247513
# Monocytes                0.642508   22.887283    1.355752   61.368153
# Plasma B cells           0.723430  685.624634    0.582690    0.540169
# Pre B cells              0.445436  265.337341    0.839574   81.031075
# Pro B cells              0.408828  217.169571    0.302723   77.668144
# pDCs                     0.667538   32.672722    0.841439   63.898666
#
#                              CD64
# scyan_pop
# Basophils                0.616813
# CD16+ NK cells           0.540172
# CD16- NK cells           0.535874
# CD34+CD38+CD123+ HSPCs   0.685287
# CD34+CD38+CD123- HSPCs   0.690035
# CD34+CD38lo HSCs         0.637662
# CD4 T cells              0.488431
# CD8 T cells              0.420792
# Mature B cells           1.175673
# Monocytes               29.381346
# Plasma B cells           0.421691
# Pre B cells              0.724887
# Pro B cells              0.502885
# pDCs                     0.704037
